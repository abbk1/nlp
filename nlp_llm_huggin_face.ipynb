# %%
import pandas as pd
# pd.set_option('display.max_colwidth', None)

# %%
# from pathlib import Path
# # Find the folder where your notebook is located
# NOTEBOOK_DIR = Path.cwd()
# # If using pathlib, construct the path dynamically
# # If the "Data" folder is sitting inside "Course Materials" relative to the notebook:
# # file_path = NOTEBOOK_DIR / "Course Materials" / "Data" / "Popchip.xlsx"
# data_path = NOTEBOOK_DIR / "Course Materials" / "Data" / "movie_reviews_sentiment.csv"

# # read in the pop chip reviews
# reviews = pd.read_csv(data_path)
# reviews.head(2)

# %%
# read in the pop chip reviews
df = pd.read_csv('movie_reviews_sentiment.csv')
df.head(2)
# Out:
#         movie_title rating                 genre in_theaters_date  \
# 0   A Dog's Journey     PG  Drama, Kids & Family          5/17/19
# 1  A Dog's Way Home     PG                 Drama          1/11/19
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     movie_info  \
# ...

# %%
import torch
from transformers import pipeline

# %%
sent_analyzer = pipeline("sentiment-analysis", # set the task to sentiment analysis
                              model="distilbert/distilbert-base-uncased-finetuned-sst-2-english", # specify the default distilbert model
                              device=-1,
                              dtype=None) # use the computer's cpu
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sent_analyzer = pipeline("sentiment-analysis", # set the task to sentiment analysis
#       2                               model="distilbert/distilbert-base-uncased-finetuned-sst-2-english", # specify the default distilbert model
#       3                               device=-1,
#       4                               dtype=None) # use the computer's cpu
#
# File ~\Documents\nlp\venv\Lib\site-packages\transformers\pipelines\__init__.py:1033, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, video_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1031 if isinstance(model, str):
#    1032     model_classes = targeted_task["pt"]
# -> 1033     model = load_model(
# ...

# %%
import sys
import torch
import transformers

print(sys.executable)
print(torch.__version__)
print(transformers.__version__)
print(transformers.is_torch_available())
# Out:
# c:\Users\ABK\Documents\nlp\venv\Scripts\python.exe
# 2.13.0+cpu
# 5.15.1
# False
